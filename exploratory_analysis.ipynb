# %% [markdown]
# <a href="https://colab.research.google.com/github/ezer2002/pfe/blob/main/exploratory_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the combined dataset
df = pd.read_csv('premier_league_combined.csv')

# Convert Date to datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Matches per season
matches_per_season = df.groupby('Season').size()

# Goals scored
df['TotalGoals'] = df['FTHG'] + df['FTAG']

# Home advantage
home_wins = (df['FTR'] == 'H').mean()

# %%
df.head()
# Out:
#     Season       SourceFile       Date     HomeTeam        AwayTeam  FTHG  \
# 0  1993-94  season-9394.csv 1993-08-14      Arsenal        Coventry     0
# 1  1993-94  season-9394.csv 1993-08-14  Aston Villa             QPR     4
# 2  1993-94  season-9394.csv 1993-08-14      Chelsea       Blackburn     1
# 3  1993-94  season-9394.csv 1993-08-14    Liverpool  Sheffield Weds     2
# 4  1993-94  season-9394.csv 1993-08-14     Man City           Leeds     1
#
#    FTAG FTR  HTHG  HTAG  ... AST  HF  AF  HC  AC  HY  AY  HR  AR  TotalGoals
# 0     3   A   NaN   NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN           3
# 1     1   H   NaN   NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN           5
# 2     2   A   NaN   NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN           3
# 3     0   H   NaN   NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN           2
# 4     1   D   NaN   NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN           2
#
# [5 rows x 25 columns]
